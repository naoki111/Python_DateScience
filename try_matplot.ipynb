# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(0,10,100)

# %%
fig = plt.figure()

# %%
plt.plot(x,np.sin(x), '-')

# %%
plt.plot(x,np.cos(x), '--')

# %%
plt.show()

# %%
p_x = np.random.rand(100)

# %%
p_y = np.random.rand(100)

# %%
plt.scatter(p_x,p_y)

# %%
data = np.random.randn(10000)

# %%
plt.hist(data)
# Out:
# (array([  24.,  211.,  903., 2203., 3111., 2322.,  967.,  229.,   24.,
#            6.]),
#  array([-3.60296183, -2.80776639, -2.01257096, -1.21737553, -0.42218009,
#          0.37301534,  1.16821077,  1.9634062 ,  2.75860164,  3.55379707,
#          4.3489925 ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.linspace(0,10,100)

# %%
fig = plt.figure()

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.cos(x), '--')

# %%
fig.savefig('test3.png')

# %%
left = np.array([1, 2, 3, 4, 5])
height = np.array([100, 200, 300, 400, 500])
plt.bar(left, height)
# Out:
# <BarContainer object of 5 artists>
